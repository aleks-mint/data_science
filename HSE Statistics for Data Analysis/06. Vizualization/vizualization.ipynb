# %%
import pandas as pd

# %% [markdown]
# Описание данных
#
# – Title — название дела, рассматриваемого в суде
#
# – Date — дата вынесения решения
#
# – Issue — номер заседания
#
# – Judge1, Judge2, Judge3 — имена судей
#
# – Vote1, Vote2, Vote3 — голос судьи (либеральный = 1, консервативный = 0)
#
# – Category — категория дела

# %%
df = pd.read_csv("/content/TenthCircuit.csv")

# %%
df.head()
# Out:
#                                Title      Date  Issue   Judge1    Judge2  \
# 0         Hansen v. SkyWest Airlines  12/21/16      1  Briscoe     McKay
# 1         Hansen v. SkyWest Airlines  12/21/16      2  Briscoe     McKay
# 2                  Glapion v. Jewell  12/14/16      1   Lucero    Holmes
# 3                       Dye v. Moniz  12/06/16      1   Lucero    Holmes
# 4  Lister v. City of Wichita, Kansas  11/15/16      1   Lucero  Matheson
#
#       Judge3  Vote1  Vote2  Vote3   Category
# 0   Matheson      1      1      1  Title VII
# 1   Matheson      0      0      0  Title VII
# 2     Moritz      0      0      0  Title VII
# 3     Moritz      0      0      0  Title VII
# 4  Bacharach      0      0      0  Title VII

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     954 non-null    object
#  1   Date      954 non-null    object
#  2   Issue     954 non-null    int64
#  3   Judge1    954 non-null    object
#  4   Judge2    954 non-null    object
#  5   Judge3    954 non-null    object
#  6   Vote1     954 non-null    int64
#  7   Vote2     954 non-null    int64
#  8   Vote3     954 non-null    int64
#  9   Category  954 non-null    object
# dtypes: int64(4), object(6)
# memory usage: 74.7+ KB

# %% [markdown]
# Какой график лучше всех подойдет для визуализации тренда суммарного количества всех рассмотренных дел за каждый год? Выберите один верный ответ.

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 954 entries, 0 to 953
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     954 non-null    object
#  1   Date      954 non-null    datetime64[ns]
#  2   Issue     954 non-null    int64
#  3   Judge1    954 non-null    object
#  4   Judge2    954 non-null    object
#  5   Judge3    954 non-null    object
#  6   Vote1     954 non-null    int64
#  7   Vote2     954 non-null    int64
#  8   Vote3     954 non-null    int64
#  9   Category  954 non-null    object
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 74.7+ KB

# %%
group_df = df.groupby(df["Date"].dt.year)

# %%
group_df[""]

# %% [markdown]
# Укажите, верно ли следующее утверждение: для визуализации суммарного количества дел по каждой категории (переменная Category) подойдет столбчатая диаграмма..

# %% [markdown]
# Выберите только те наблюдения, где все судьи голосовали одинаково. Постройте столбчатую диаграмму для суммарного количества заседаний по каждой категории и определите, каких заседаний и в какой категории дел больше — тех, где судьи голосовали либерально, или тех, где голоса были консервативны. Выберите один верный ответ.

# %%
odin = df[(df["Vote1"] == 1) & (df["Vote2"] == 1) & (df["Vote3"] == 1) | (df["Vote1"] == 0) & (df["Vote2"] == 0) & (df["Vote3"] == 0)]

# %%
odin
# Out:
#                                  Title       Date  Issue     Judge1  \
# 0           Hansen v. SkyWest Airlines 2016-12-21      1    Briscoe
# 1           Hansen v. SkyWest Airlines 2016-12-21      2    Briscoe
# 2                    Glapion v. Jewell 2016-12-14      1     Lucero
# 3                         Dye v. Moniz 2016-12-06      1     Lucero
# 4    Lister v. City of Wichita, Kansas 2016-11-15      1     Lucero
# ..                                 ...        ...    ...        ...
# 949                Haimour v. Gonzales 2006-01-31      1      Henry
# 950               Infanzon v. Gonzales 2006-01-24      1      Henry
# 951                  Otero v. Gonzales 2006-01-24      1  Tymkovich
# 952                Infanzon v. Comfort 2006-01-18      1    Briscoe
# 953                    Wei v. Gonzales 2006-01-09      1    Briscoe
#
#         Judge2     Judge3  Vote1  Vote2  Vote3     Category
# 0        McKay   Matheson      1      1      1    Title VII
# 1        McKay   Matheson      0      0      0    Title VII
# 2       Holmes     Moritz      0      0      0    Title VII
# 3       Holmes     Moritz      0      0      0    Title VII
# 4     Matheson  Bacharach      0      0      0    Title VII
# ..         ...        ...    ...    ...    ...          ...
# 949      McKay     Murphy      0      0      0  Immigration
# 950      McKay     Murphy      0      0      0  Immigration
# 951   Porfilio    Baldock      0      0      0  Immigration
# 952     Lucero     Murphy      0      0      0  Immigration
# 953  McConnell  Tymkovich      0      0      0  Immigration
#
# [934 rows x 10 columns]

# %%
df["Category"].value_counts()
# Out:
# Immigration    554
# Title VII      400
# Name: Category, dtype: int64

# %%
odin[odin["Category"] == "Immigration"]["Vote1"].value_counts()
# Out:
# 0    500
# 1     47
# Name: Vote1, dtype: int64

# %%
odin[odin["Category"] == "Title VII"]["Vote1"].value_counts()
# Out:
# 0    328
# 1     59
# Name: Vote1, dtype: int64

# %%
odin.plot.bar(x="Category", y="Issue")

# %% [markdown]
# Выберите заседания только за 2016 год. Постройте линейный график и определите, в каких месяцах наблюдались пиковые значения по числу заседаний. Будьте внимательны — даты записаны в формате месяц/день/год. Выберите один верный ответ.

# %%
df2016 = df[df["Date"].dt.year == 2016]

# %%
df2016["Date"].dt.month.value_counts()
# Out:
# 1     11
# 4      9
# 8      7
# 7      6
# 12     5
# 9      4
# 3      4
# 2      4
# 6      2
# 11     1
# 10     1
# 5      1
# Name: Date, dtype: int64

# %%
df2016[(df2016["Date"].dt.month == 1)]
# Out:
#                                                Title       Date  Issue  \
# 19                 Unal v. Los Alamos Public Schools 2016-01-29      1
# 20                 Unal v. Los Alamos Public Schools 2016-01-29      2
# 21                               Hannah v. Cowlishaw 2016-01-29      1
# 22   Montoya v. Hunter Douglas Window Fashions, Inc. 2016-01-25      1
# 23                                 Mancell v. McHugh 2016-01-25      1
# 24                       L'Ggrke v. Asset Plus Corp. 2016-01-20      1
# 25     Lewis v. Twenty-First Century Bean Processing 2016-01-06      1
# 425                                   Zhang v. Lynch 2016-01-29      1
# 426                                    Guru v. Lynch 2016-01-26      1
# 427                        Gutierrez-Orozco v. Lynch 2016-01-21      1
# 428                             Daoi Kai He v. Lynch 2016-01-12      1
#
#         Judge1   Judge2     Judge3  Vote1  Vote2  Vote3     Category
# 19     Briscoe   Lucero     McHugh      1      1      1    Title VII
# 20     Briscoe   Lucero     McHugh      0      0      0    Title VII
# 21      Lucero  Gorsuch     McHugh      0      0      0    Title VII
# 22    Phillips   McHugh     Moritz      0      0      0    Title VII
# 23       Hartz  Baldock     Holmes      0      0      0    Title VII
# 24       Hartz  Baldock     Holmes      0      0      0    Title VII
# 25     Gorsuch    McKay  Bacharach      0      0      0    Title VII
# 425      Hartz  Baldock     Holmes      0      0      0  Immigration
# 426      Kelly   Lucero     McHugh      0      0      0  Immigration
# 427  Bacharach  O'Brien   Phillips      0      0      0  Immigration
# 428  Tymkovich    Hartz     Moritz      0      0      0  Immigration

# %%
df2016[(df2016["Date"].dt.month == 4)]
# Out:
#                                                  Title       Date  Issue  \
# 13           Johnson v. Oklahoma Department of Transp. 2016-04-20      1
# 14                                    Walton v. Powell 2016-04-19      1
# 15                      Aman v. Dillon Companies, Inc. 2016-04-15      1
# 16   McGowan v. Board of Trustees of Metropolitan S... 2016-04-13      1
# 17           Robinson v. St. John Medical Center, Inc. 2016-04-13      1
# 18            Tuffa v. Flight Services & Systems, Inc. 2016-04-05      1
# 414                                    Garcia v. Lynch 2016-04-28      1
# 415                                 Ontiveros v. Lynch 2016-04-27      1
# 416                                      Htun v. Lynch 2016-04-08      1
#
#       Judge1    Judge2     Judge3  Vote1  Vote2  Vote3     Category
# 13   Gorsuch     McKay  Bacharach      0      0      0    Title VII
# 14   Gorsuch    Murphy     Moritz      1      1      1    Title VII
# 15   Briscoe    Lucero     McHugh      0      0      0    Title VII
# 16   Briscoe    Lucero     McHugh      0      0      0    Title VII
# 17   Gorsuch  Matheson     Moritz      0      0      0    Title VII
# 18   Gorsuch     McKay  Bacharach      0      0      0    Title VII
# 414    Kelly  Porfilio    Baldock      0      0      0  Immigration
# 415  Gorsuch  Matheson     Moritz      0      0      0  Immigration
# 416    Hartz   Baldock     McHugh      0      0      0  Immigration

# %% [markdown]
# Используя исходные данные, определите среднее число заседаний за каждый сезон (зима, весна, лето, осень). Постройте столбчатую диаграмму, определите месяц с наибольшим показателем. Будьте внимательны — даты записаны в формате месяц/день/год. Введите ответ в виде слова (например, осень).

# %%
df[(df["Date"].dt.month == 1) | (df["Date"].dt.month == 2) |(df["Date"].dt.month == 12)]
# Out:
#                                  Title       Date  Issue     Judge1  \
# 0           Hansen v. SkyWest Airlines 2016-12-21      1    Briscoe
# 1           Hansen v. SkyWest Airlines 2016-12-21      2    Briscoe
# 2                    Glapion v. Jewell 2016-12-14      1     Lucero
# 3                         Dye v. Moniz 2016-12-06      1     Lucero
# 19   Unal v. Los Alamos Public Schools 2016-01-29      1    Briscoe
# ..                                 ...        ...    ...        ...
# 949                Haimour v. Gonzales 2006-01-31      1      Henry
# 950               Infanzon v. Gonzales 2006-01-24      1      Henry
# 951                  Otero v. Gonzales 2006-01-24      1  Tymkovich
# 952                Infanzon v. Comfort 2006-01-18      1    Briscoe
# 953                    Wei v. Gonzales 2006-01-09      1    Briscoe
#
#         Judge2     Judge3  Vote1  Vote2  Vote3     Category
# 0        McKay   Matheson      1      1      1    Title VII
# 1        McKay   Matheson      0      0      0    Title VII
# 2       Holmes     Moritz      0      0      0    Title VII
# 3       Holmes     Moritz      0      0      0    Title VII
# 19      Lucero     McHugh      1      1      1    Title VII
# ..         ...        ...    ...    ...    ...          ...
# 949      McKay     Murphy      0      0      0  Immigration
# 950      McKay     Murphy      0      0      0  Immigration
# 951   Porfilio    Baldock      0      0      0  Immigration
# 952     Lucero     Murphy      0      0      0  Immigration
# 953  McConnell  Tymkovich      0      0      0  Immigration
#
# [264 rows x 10 columns]

# %%
df[(df["Date"].dt.month == 3) | (df["Date"].dt.month == 4) |(df["Date"].dt.month == 5)]
# Out:
#                                                  Title       Date  Issue  \
# 12                                   Glapion v. Castro 2016-05-12      1
# 13           Johnson v. Oklahoma Department of Transp. 2016-04-20      1
# 14                                    Walton v. Powell 2016-04-19      1
# 15                      Aman v. Dillon Companies, Inc. 2016-04-15      1
# 16   McGowan v. Board of Trustees of Metropolitan S... 2016-04-13      1
# ..                                                 ...        ...    ...
# 940                                  Sondh v. Gonzales 2006-03-28      1
# 941                           Herrera-Ceja v. Gonzales 2006-03-28      1
# 942                              Panjaitan v. Gonzales 2006-03-28      1
# 943                                 Al-Ani v. Gonzales 2006-03-20      1
# 944                                    Yan v. Gonzales 2006-03-02      1
#
#         Judge1    Judge2     Judge3  Vote1  Vote2  Vote3     Category
# 12       Kelly   O'Brien    Gorsuch      0      0      0    Title VII
# 13     Gorsuch     McKay  Bacharach      0      0      0    Title VII
# 14     Gorsuch    Murphy     Moritz      1      1      1    Title VII
# 15     Briscoe    Lucero     McHugh      0      0      0    Title VII
# 16     Briscoe    Lucero     McHugh      0      0      0    Title VII
# ..         ...       ...        ...    ...    ...    ...          ...
# 940      Hartz      Ebel  Tymkovich      0      0      0  Immigration
# 941     Lucero      Ebel     Murphy      0      0      0  Immigration
# 942     Murphy   Seymour  McConnell      0      0      0  Immigration
# 943      Henry     McKay     Murphy      0      0      0  Immigration
# 944  McConnell  Anderson    Baldock      1      1      1  Immigration
#
# [234 rows x 10 columns]

# %%
df[(df["Date"].dt.month == 6) | (df["Date"].dt.month == 7) |(df["Date"].dt.month == 8)]
# Out:
#                                          Title       Date  Issue     Judge1  \
# 6         Chung v. El Paso School District #11 2016-08-11      1      Hartz
# 7                     Bird v. West Valley City 2016-08-08      1   Matheson
# 8                Drury v. BNSF Railway Company 2016-08-02      1  Tymkovich
# 9     Callahan v. Communication Graphics, Inc. 2016-07-21      1    Gorsuch
# 10                           Williams v. McKee 2016-07-20      1  Tymkovich
# ..                                         ...        ...    ...        ...
# 927                        Bastian v. Gonzales 2006-07-06      1  McConnell
# 928  Vargas v. Department Of Homeland Security 2006-06-21      1      Hartz
# 929                          Schmitt v. Maurer 2006-06-20      1     Lucero
# 930                    Ballesteros v. Ashcroft 2006-06-14      1      Henry
# 931                          Peter v. Gonzales 2006-06-13      1     Lucero
#
#        Judge2     Judge3  Vote1  Vote2  Vote3     Category
# 6      Holmes     McHugh      0      0      0    Title VII
# 7     Baldock     Moritz      0      0      0    Title VII
# 8      Lucero  Bacharach      0      0      0    Title VII
# 9     Baldock     McHugh      0      0      0    Title VII
# 10     Murphy  Bacharach      0      0      0    Title VII
# ..        ...        ...    ...    ...    ...          ...
# 927  Anderson    Baldock      0      0      0  Immigration
# 928      Ebel  Tymkovich      0      0      0  Immigration
# 929   Baldock  McConnell      0      0      0  Immigration
# 930     McKay  Tymkovich      0      0      0  Immigration
# 931      Ebel     Murphy      0      0      0  Immigration
#
# [260 rows x 10 columns]

# %%
df[(df["Date"].dt.month == 9) | (df["Date"].dt.month == 10) | (df["Date"].dt.month == 11)]
# Out:
#                                  Title       Date  Issue     Judge1  \
# 4    Lister v. City of Wichita, Kansas 2016-11-15      1     Lucero
# 5                ElHelbawy v. Pritzker 2016-10-13      1  Tymkovich
# 29                Sanders v. Anoatubby 2015-11-23      1    Gorsuch
# 30     McElroy v. American Family Ins. 2015-10-30      1    Briscoe
# 31             Hung Thai Pham v. James 2015-10-20      1  Tymkovich
# ..                                 ...        ...    ...        ...
# 909                  Umboh v. Gonzales 2006-10-05      1      Hartz
# 910                 Mondal v. Gonzales 2006-10-04      1      Henry
# 911               Asagwara v. Gonzales 2006-09-18      1    O'Brien
# 912                  Thorn v. Gonzales 2006-09-13      1      Tacha
# 913           Garcia-Ortiz v. Gonzales 2006-09-06      1      Henry
#
#         Judge2     Judge3  Vote1  Vote2  Vote3     Category
# 4     Matheson  Bacharach      0      0      0    Title VII
# 5    Bacharach     Moritz      0      0      0    Title VII
# 29     O'Brien  Bacharach      0      0      0    Title VII
# 30      Holmes     Moritz      0      0      0    Title VII
# 31      Holmes     McHugh      0      0      0    Title VII
# ..         ...        ...    ...    ...    ...          ...
# 909   Holloway    Baldock      0      0      0  Immigration
# 910   Anderson  McConnell      0      0      0  Immigration
# 911   Porfilio   Anderson      0      0      0  Immigration
# 912    O'Brien  McConnell      0      0      0  Immigration
# 913    Briscoe     Murphy      0      0      0  Immigration
#
# [196 rows x 10 columns]

# %% [markdown]
# Выберите только заседания по категории иммиграции. Постройте столбчатую диаграмму по суммарному числу заседаний, на котором присутствовал каждый судья. В ответ запишите имя судьи, который принимал участие в наибольшем количестве заседаний (например, Holmes).

# %%
cat_df = df[df["Category"] == "Immigration"]

# %%
name_df = pd.concat([cat_df["Judge1"], cat_df["Judge2"], cat_df["Judge3"]])

# %%
name_df.value_counts()
# Out:
# Tymkovich     122
# Hartz         105
# Lucero        102
# Porfilio      100
# Holmes         96
# Baldock        96
# Anderson       95
# O'Brien        91
# Kelly          90
# Briscoe        84
# McKay          80
# Brorby         78
# Ebel           68
# Murphy         61
# Matheson       61
# Gorsuch        51
# Tacha          42
# McConnell      37
# Bacharach      36
# Henry          31
# Phillips       30
# Holloway       26
# McHugh         24
# Moritz         23
# Seymour        14
# Brown           4
# Mcwilliams      2
# Eagan           2
# Arguello        2
# Figa            2
# Kane            2
# Siler           1
# Barrett         1
# Armijo          1
# Frizzell        1
# Johnson         1
# dtype: int64

# %% [markdown]
# Определите, какие дела (переменная Title) рассматривались чаще всего. Постройте столбчатую диаграмму по суммарному числу таких заседаний, на котором присутствовал каждый судья. В ответ запишите имя судьи, который принимал участие в наибольшем количестве заседаний (например, Holmes).

# %%
df["Title"].value_counts()[0:5]
# Out:
# Tabor v. Hilti, Inc.                           3
# Semsroth v. City of Wichita                    3
# Garcia v. Holder                               3
# Singh v. Holder                                3
# Flitton v. Primary Residential Mortg., Inc.    3
# Name: Title, dtype: int64

# %%
new_name_df = df[(df["Title"] == "Tabor v. Hilti, Inc.") | (df["Title"] == "Semsroth v. City of Wichita") |(df["Title"] == "Garcia v. Holder") |(df["Title"] == "Singh v. Holder") |(df["Title"] == "Flitton v. Primary Residential Mortg., Inc.")]

# %%
new_name_df
# Out:
#                                            Title       Date  Issue     Judge1  \
# 69                          Tabor v. Hilti, Inc. 2014-09-02      1      Hartz
# 125                         Tabor v. Hilti, Inc. 2013-01-15      1     Lucero
# 126                         Tabor v. Hilti, Inc. 2013-01-15      2     Lucero
# 218  Flitton v. Primary Residential Mortg., Inc. 2010-08-05      1      Tacha
# 219  Flitton v. Primary Residential Mortg., Inc. 2010-08-05      2      Tacha
# 263                  Semsroth v. City of Wichita 2009-02-17      1     Murphy
# 268                  Semsroth v. City of Wichita 2008-12-22      1     Lucero
# 269                  Semsroth v. City of Wichita 2008-12-22      2     Lucero
# 323  Flitton v. Primary Residential Mortg., Inc. 2007-08-03      1     Lucero
# 472                             Garcia v. Holder 2015-03-24      1     Moritz
# 534                              Singh v. Holder 2014-03-11      1  Tymkovich
# 610                              Singh v. Holder 2012-10-09      1   Matheson
# 654                             Garcia v. Holder 2011-10-14      1     Murphy
# 747                             Garcia v. Holder 2009-10-27      1     Lucero
# 779                              Singh v. Holder 2009-03-31      1      Tacha
#
#         Judge2    Judge3  Vote1  Vote2  Vote3     Category
# 69   Tymkovich    Holmes      0      0      0    Title VII
# 125    O'Brien  Matheson      1      1      1    Title VII
# 126    O'Brien  Matheson      0      0      0    Title VII
# 218      McKay   Gorsuch      1      0      1    Title VII
# 219      McKay   Gorsuch      0      0      1    Title VII
# 263      McKay  Anderson      0      0      0    Title VII
# 268   Holloway      Ebel      1      1      1    Title VII
# 269   Holloway      Ebel      0      0      0    Title VII
# 323     Murphy   Gorsuch      1      1      1    Title VII
# 472   Porfilio   Baldock      0      0      0  Immigration
# 534   Porfilio   Baldock      0      0      0  Immigration
# 610   Porfilio   Baldock      0      0      0  Immigration
# 654   Anderson     Hartz      0      0      0  Immigration
# 747    Baldock    Murphy      0      0      0  Immigration
# 779     Murphy     Hartz      0      0      0  Immigration

# %%
pd.concat([new_name_df["Judge1"], new_name_df["Judge2"], new_name_df["Judge3"]]).value_counts()
# Out:
# Lucero       6
# Murphy       5
# Baldock      4
# Hartz        3
# Tacha        3
# Matheson     3
# McKay        3
# Porfilio     3
# Gorsuch      3
# Tymkovich    2
# O'Brien      2
# Holloway     2
# Anderson     2
# Ebel         2
# Moritz       1
# Holmes       1
# dtype: int64

# %% [markdown]
# Обратите внимание на то, как в каждом деле голосовали судьи. Постройте столбчатую диаграмму и определите, каких решений, принятых большинством (2 и более) голосов, больше. Укажите, верно ли следующее утверждение: решений, где большинство судей голосовало консервативно, больше.

# %%
cons_df = df[(df["Vote1"] == 0) & (df["Vote2"] == 0) & (df["Vote3"] == 0) | (df["Vote1"] == 0) & (df["Vote2"] == 0) & (df["Vote3"] == 1) | (df["Vote1"] == 0) & (df["Vote2"] == 1) & (df["Vote3"] == 0) | (df["Vote1"] == 1) & (df["Vote2"] == 0) & (df["Vote3"] == 0) ]

# %%
cons_df.shape
# Out:
# (840, 10)

# %%
df.shape
# Out:
# (954, 10)

# %% [markdown]
# Выберите только те заседания, в которых участвовал судья Lucero. Постройте линейный график и определите, в каком году он участвовал в заседаниях меньше всего. Будьте внимательны — даты записаны в формате месяц/день/год. В ответ запишите целое число (например, 2016).

# %%
df[(df["Judge1"] == "Lucero") | (df["Judge2"] == "Lucero") | (df["Judge3"] == "Lucero")]["Date"].dt.year.value_counts()
# Out:
# 2007    22
# 2014    21
# 2008    20
# 2006    20
# 2012    17
# 2015    15
# 2016    14
# 2013    14
# 2011    13
# 2010    12
# 2009     9
# Name: Date, dtype: int64
