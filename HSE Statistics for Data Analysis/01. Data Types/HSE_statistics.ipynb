# %%
import pandas as pd

# %%
df = pd.read_csv('/content/StarWars.csv', sep=";")

# %% [markdown]
# Описание данных
# – respondentID — идентификационный номер респондента
# – seen — ответ на вопрос, видел ли респондент хотя бы один фильм из серии «Звездных войн» (да/нет)
# – fan — ответ на вопрос, считает ли респондент себя фанатом серии фильмов (да/нет)
# – gender — пол респондента (М/Ж)
# – age_group — возрастная группа, к которой принадлежит респондент (18-29, 30-44, 45-60, > 60)
# – income — доход респондента в долларах США (0 - 24.999, 25.000 - 49.999, 50.000 - 99.999, 100.000 - 149.999, 150.000+)
# – loc — регион проживания респондента (в США)
# – yoda — отношение респондента к персонажу серии (Йоде)
# – princess_leia_organa — отношение респондента к персонажу серии (принцессе Лее Органе)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186 entries, 0 to 1185
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   respondentID          1186 non-null   int64
#  1   seen                  1186 non-null   object
#  2   fan                   836 non-null    object
#  3   gender                1046 non-null   object
#  4   age_group             1046 non-null   object
#  5   income                858 non-null    object
#  6   loc                   1043 non-null   object
#  7   yoda                  826 non-null    object
#  8   princess_leia_organa  831 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 83.5+ KB

# %%
df.age_group
# Out:
# 0       18-29
# 1       18-29
# 2       18-29
# 3       18-29
# 4       18-29
#         ...
# 1181    18-29
# 1182    30-44
# 1183    30-44
# 1184    45-60
# 1185     > 60
# Name: age_group, Length: 1186, dtype: object

# %% [markdown]
# Укажите, верно ли следующее утверждение: все женщины старше 60 лет, входящие в категорию с наивысшим доходом и являющиеся фанатами серии фильмов, проживают в одном регионе.

# %%
df[(df["age_group"] == "> 60") & (df["gender"] == "Ж") & (df["income"] == "150.000+") & (df["fan"] == "да")]
# Out:
#      respondentID seen fan gender age_group    income  \
# 162    3291141478   да  да      Ж      > 60  150.000+
# 522    3290342102   да  да      Ж      > 60  150.000+
# 671    3289963393   да  да      Ж      > 60  150.000+
#
#                              loc            yoda princess_leia_organa
# 162                Тихоокеанский  очень нравится       очень нравится
# 522  Северо-Западный центральный  очень нравится       очень нравится
# 671                       Горный  очень нравится       очень нравится

# %% [markdown]
# Какой регион проживания чаще всего встречается в данных? Выберите один верный ответ.

# %%
df["loc"].value_counts()
# Out:
# Северо-Восточный центральный    181
# Тихоокеанский                   175
# Южно-Атлантический              170
# Средне-Атлантический            122
# Юго-Западный центральный        110
# Северо-Западный центральный      93
# Горный                           79
# Новая Англия                     75
# Юго-Восточный центральный        38
# Name: loc, dtype: int64

# %% [markdown]
# Сколько респондентов не назвали свой доход? Выберите один верный ответ.

# %%
df["income"].isnull().sum()
# Out:
# 328

# %% [markdown]
# Скольким респондентам одновременно очень нравятся Йода и принцесса Лея Органа? Выберите один верный ответ.

# %%
df["yoda"].value_counts()
# Out:
# очень нравится              605
# нравится                    144
# отношусь нейтрально          51
# не знаю такого персонажа     10
# очень не нравится             8
# не нравится                   8
# Name: yoda, dtype: int64

# %%
df["princess_leia_organa"].value_counts()
# Out:
# очень нравится              547
# нравится                    210
# отношусь нейтрально          48
# не нравится                  12
# не знаю такого персонажа      8
# очень не нравится             6
# Name: princess_leia_organa, dtype: int64

# %%
df[(df["yoda"] == "очень нравится") & (df["princess_leia_organa"] == "очень нравится")]
# Out:
#       respondentID seen  fan gender age_group             income  \
# 0       3292879998   да   да      М     18-29                NaN
# 3       3292763116   да   да      М     18-29  100.000 - 149.999
# 5       3292719380   да   да      М     18-29    25.000 - 49.999
# 7       3292663732   да   да      М     18-29                NaN
# 9       3292640424   да  нет      М     18-29    25.000 - 49.999
# ...            ...  ...  ...    ...       ...                ...
# 1177    3288396374   да  нет      М      > 60    50.000 - 99.999
# 1179    3288391812   да   да      Ж     45-60         0 - 24.999
# 1180    3288389603   да   да      Ж     45-60         0 - 24.999
# 1182    3288378779   да   да      Ж     30-44    50.000 - 99.999
# 1184    3288373068   да   да      Ж     45-60  100.000 - 149.999
#
#                                loc            yoda princess_leia_organa
# 0               Южно-Атлантический  очень нравится       очень нравится
# 3      Северо-Западный центральный  очень нравится       очень нравится
# 5             Средне-Атлантический  очень нравится       очень нравится
# 7               Южно-Атлантический  очень нравится       очень нравится
# 9                    Тихоокеанский  очень нравится       очень нравится
# ...                            ...             ...                  ...
# 1177                 Тихоокеанский  очень нравится       очень нравится
# 1179   Северо-Западный центральный  очень нравится       очень нравится
# 1180                 Тихоокеанский  очень нравится       очень нравится
# 1182                        Горный  очень нравится       очень нравится
# 1184  Северо-Восточный центральный  очень нравится       очень нравится
#
# [462 rows x 9 columns]

# %% [markdown]
# Сколько респондентов не видели ни одного фильма серии, но считают себя ее фанатами? Введите ответ в виде целого числа.

# %%
df[(df["seen"] == "нет") & (df["fan"] == "да")]
# Out:
# Empty DataFrame
# Columns: [respondentID, seen, fan, gender, age_group, income, loc, yoda, princess_leia_organa]
# Index: []

# %%
df["seen"].value_counts()
# Out:
# да     936
# нет    250
# Name: seen, dtype: int64

# %%
df[(df["gender"] == "М")]
# Out:
#       respondentID seen  fan gender age_group             income  \
# 0       3292879998   да   да      М     18-29                NaN
# 1       3292879538  нет  NaN      М     18-29         0 - 24.999
# 2       3292765271   да  нет      М     18-29         0 - 24.999
# 3       3292763116   да   да      М     18-29  100.000 - 149.999
# 4       3292731220   да   да      М     18-29  100.000 - 149.999
# ...            ...  ...  ...    ...       ...                ...
# 1153    3288429390  нет  NaN      М     30-44    50.000 - 99.999
# 1157    3288423088  нет  NaN      М     45-60  100.000 - 149.999
# 1164    3288415166   да  нет      М     45-60  100.000 - 149.999
# 1169    3288408698   да   да      М     45-60    25.000 - 49.999
# 1177    3288396374   да  нет      М      > 60    50.000 - 99.999
#
#                               loc                      yoda  \
# 0              Южно-Атлантический            очень нравится
# 1        Юго-Западный центральный                       NaN
# 2     Северо-Западный центральный  не знаю такого персонажа
# 3     Северо-Западный центральный            очень нравится
# 4     Северо-Западный центральный                  нравится
# ...                           ...                       ...
# 1153     Юго-Западный центральный                       NaN
# 1157         Средне-Атлантический                       NaN
# 1164         Средне-Атлантический       отношусь нейтрально
# 1169           Южно-Атлантический            очень нравится
# 1177                Тихоокеанский            очень нравится
#
#      princess_leia_organa
# 0          очень нравится
# 1                     NaN
# 2                нравится
# 3          очень нравится
# 4                нравится
# ...                   ...
# 1153                  NaN
# 1157                  NaN
# 1164             нравится
# 1169       очень нравится
# 1177       очень нравится
#
# [497 rows x 9 columns]

# %% [markdown]
# Посмотрите на мужчин, проживающих в горном районе. В ответ запишите ID респондента, входящего в категорию с наивысшим доходом при заданных условиях.

# %%
df[(df["gender"] == "М") & (df["loc"] == "Горный") & (df["income"] == "150.000+")]
# Out:
#      respondentID seen  fan gender age_group    income     loc      yoda  \
# 169    3291077381   да  нет      М     45-60  150.000+  Горный  нравится
#
#     princess_leia_organa
# 169  отношусь нейтрально

# %% [markdown]
# Укажите, верно ли следующее утверждение: фанатов серии фильмов в возрастной категории 45-60 меньше, чем не-фанатов в возрастной категории 18-29.

# %%
df[(df["fan"] == "да") & (df["age_group"] == "45-60")]
# Out:
#       respondentID seen fan gender age_group             income  \
# 143     3291364062   да  да      М     45-60                NaN
# 163     3291139156   да  да      Ж     45-60                NaN
# 175     3291052728   да  да      М     45-60    50.000 - 99.999
# 176     3291051343   да  да      М     45-60         0 - 24.999
# 177     3291045360   да  да      М     45-60                NaN
# ...            ...  ...  ..    ...       ...                ...
# 1169    3288408698   да  да      М     45-60    25.000 - 49.999
# 1175    3288401136   да  да      Ж     45-60    50.000 - 99.999
# 1179    3288391812   да  да      Ж     45-60         0 - 24.999
# 1180    3288389603   да  да      Ж     45-60         0 - 24.999
# 1184    3288373068   да  да      Ж     45-60  100.000 - 149.999
#
#                                loc            yoda princess_leia_organa
# 143             Южно-Атлантический  очень нравится       очень нравится
# 163    Северо-Западный центральный  очень нравится       очень нравится
# 175       Юго-Западный центральный  очень нравится       очень нравится
# 176           Средне-Атлантический        нравится             нравится
# 177      Юго-Восточный центральный  очень нравится       очень нравится
# ...                            ...             ...                  ...
# 1169            Южно-Атлантический  очень нравится       очень нравится
# 1175      Юго-Западный центральный        нравится             нравится
# 1179   Северо-Западный центральный  очень нравится       очень нравится
# 1180                 Тихоокеанский  очень нравится       очень нравится
# 1184  Северо-Восточный центральный  очень нравится       очень нравится
#
# [154 rows x 9 columns]

# %%
df[(df["fan"] == "нет") & (df["age_group"] == "18-29")].shape
# Out:
# (56, 9)

# %% [markdown]
# Сколько процентов (от общего числа респондентов) являются фанатами серии фильмов, проживают в Новой Англии и имеют доход 0 - 24.999 долларов? В ответ запишите число (процент от 0 до 100), округлите до целого.

# %%
df[(df["fan"] == "да") & (df["loc"] == "Новая Англия") & (df["income"] == "0 - 24.999")].shape
# Out:
# (9, 9)

# %%
df.shape
# Out:
# (1186, 9)

# %%
9 / 1186 * 100
# Out:
# 0.7588532883642496
